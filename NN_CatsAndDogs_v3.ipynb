# %% [markdown]
# # Feedforward Neural Network
# Created by Eduardo de Jesús Dávila Meza

# %% [markdown]
# ## Architecture:
# - Input layer (Image vector)
# - 3 fully connected hidden layers
# - Output layer (According to the number of classes)

# %% [markdown]
# ## Tested on:
# - Ubuntu 16.04
# - Python 3.5 and 3.7
#
# ## Requirements:
# - Matpotlib: pip3 install matplotlib
# - OpenCV: pip3 install opencv-python
# - TensorFlow 1.15 (Release for CPU-only): pip3 install tensorflow==1.15

# %%
import matplotlib.pyplot as plt
import numpy as np
import glob
import sys
# sys.path.remove('/opt/ros/kinetic/lib/python2.7/dist-packages')#If ROS Kinetic is installed
import cv2
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
from tensorflow.python.framework import ops

ops.reset_default_graph()
session = tf.Session()

# %% [markdown]
# ## Load dataset

# %%
#Height and width of the images for the training
dim = 64

#Training dataset
train_images = []
train_labels = []

# Load all cats 
files = glob.glob ("cats_and_dogs_small/train/cats/*.jpg")
for myFile in files:
    image = cv2.imread(myFile)
    image = cv2.resize(image,(dim,dim))

    train_images.append(image)

    train_labels.append(0)#Class for cats

    cv2.imshow("Cat samples - Training", image)
    cv2.waitKey(1)
cv2.destroyAllWindows()

# Load all dogs
files = glob.glob ("cats_and_dogs_small/train/dogs/*.jpg")
for myFile in files:
    image = cv2.imread(myFile)
    image = cv2.resize(image,(dim,dim))

    r = np.random.choice(len(train_labels))

    train_images.insert(r,image)

    train_labels.insert(r,1)#Class for dogs

    cv2.imshow("Dog samples - Training", image)
    cv2.waitKey(1)
cv2.destroyAllWindows()

#Input and output data
train_xdata = np.array(train_images,np.float64)/255
train_labels = np.array(train_labels,np.int32)

train_images = np.array(train_images)

#Validation dataset
validation_images = []
validation_labels = []

files = glob.glob ("cats_and_dogs_small/validation/cats/*.jpg")
for myFile in files:
    image = cv2.imread(myFile)
    image = cv2.resize(image,(dim,dim))

    validation_images.append(image)

    validation_labels.append(0)#Class for cats

    cv2.imshow("Cat samples - Validation", image)
    cv2.waitKey(1)
cv2.destroyAllWindows()

files = glob.glob ("cats_and_dogs_small/validation/dogs/*.jpg")
for myFile in files:
    image = cv2.imread(myFile)
    image = cv2.resize(image,(dim,dim))

    r = np.random.choice(len(train_labels))

    validation_images.insert(r,image)

    validation_labels.insert(r,1)#Class for dogs

    cv2.imshow("Dog samples - Validation ", image)
    cv2.waitKey(1)
cv2.destroyAllWindows()

#Input and output data
test_xdata = np.array(validation_images,np.float64)/255
test_labels = np.array(validation_labels,np.int32)

validation_images = np.array(validation_images)
validation_labels = np.array(validation_labels,np.int32)

#Print dimensions
print(train_xdata.shape)
print(train_labels.shape)

print(test_xdata.shape)
print(test_labels.shape)
# Out:
# (2000, 64, 64, 3)
# (2000,)
# (1000, 64, 64, 3)
# (1000,)

# %% [markdown]
# ## Model parameters

# %%
## For the training
epochs = 2500
eval_every = 5

batch_size = 1000
evaluation_size = 100

#For AdamOptimizer
learning_rate = 0.001
beta1 = 0.9
beta2 = 0.999

image_width = train_xdata[0].shape[0]
print(image_width)

image_height = train_xdata[0].shape[1]
print(image_height)

target_size = max(train_labels)+1
print(target_size)

## For the architecture of the neural network
num_channels = 3 #Image channels

full_connected_size1 = 1024 #Neurons in fully connected hidden layer 1 
full_connected_size2 = 256 #Neurons in fully connected hidden layer 1
full_connected_size3 = 64 #Neurons in fully connected hidden layer 1 

print(full_connected_size1)
print(full_connected_size2)
print(full_connected_size3)

sd = 0.01 #Standard deviation
# Out:
# 64
# 64
# 2
# 1024
# 256
# 64

# %%
x_input_shape = (batch_size, image_width, image_height, num_channels)
x_input = tf.placeholder(tf.float32, shape = x_input_shape)
y_target = tf.placeholder(tf.int32, shape = batch_size)

eval_input_shape = (evaluation_size, image_width, image_height, num_channels)
eval_input = tf.placeholder(tf.float32, shape = eval_input_shape)
eval_target = tf.placeholder(tf.float32, shape = evaluation_size)

# %% [markdown]
# # Fully connected layers

# %%
resulting_width = image_width 
print(resulting_width)
resulting_height = image_height 
print(resulting_height)

# Inputs for the first fully connected hidden layer
full_input_size_1 = resulting_width*resulting_height*num_channels
print(full_input_size_1)

# Fully connected hidden layer 1
full_weight_1 = tf.Variable(tf.truncated_normal([full_input_size_1,full_connected_size1], stddev = sd, dtype = tf.float32))
full_bias_1 = tf.Variable(tf.truncated_normal([full_connected_size1], stddev = sd, dtype = tf.float32))

# Fully connected hidden layer 2
full_weight_2 = tf.Variable(tf.truncated_normal([full_connected_size1,full_connected_size2], stddev = sd, dtype = tf.float32))
full_bias_2 = tf.Variable(tf.truncated_normal([full_connected_size2], stddev = sd, dtype = tf.float32))

# Fully connected hidden layer 3
full_weight_3 = tf.Variable(tf.truncated_normal([full_connected_size2,full_connected_size3], stddev = sd, dtype = tf.float32))
full_bias_3 = tf.Variable(tf.truncated_normal([full_connected_size3], stddev = sd, dtype = tf.float32))

# Last fully connected layer (output layer)
last_full_weight = tf.Variable(tf.truncated_normal([full_connected_size3,target_size], stddev = sd, dtype = tf.float32))
last_full_bias = tf.Variable(tf.truncated_normal([target_size], stddev = sd, dtype = tf.float32))
# Out:
# 64
# 64
# 12288

# %%
def my_conv_neural_net(input_data):
    # Input layer. Flat the image channels in a vector
    final_conv_shape = input_data.get_shape().as_list()  
    final_shape = final_conv_shape[1]*final_conv_shape[2]*final_conv_shape[3]
    flat_output = tf.reshape(input_data, [final_conv_shape[0], final_shape]) 

    # Fully connected hidden layer 1
    fully_connected_1 = tf.nn.relu(tf.add(tf.matmul(flat_output, full_weight_1), full_bias_1))

    # Fully connected hidden layer 2
    fully_connected_2 = tf.nn.relu(tf.add(tf.matmul(fully_connected_1, full_weight_2), full_bias_2))

    # Fully connected hidden layer 3
    fully_connected_3 = tf.nn.relu(tf.add(tf.matmul(fully_connected_2, full_weight_3), full_bias_3))

    # Output layer
    last_fully_connected = tf.add(tf.matmul(fully_connected_3, last_full_weight), last_full_bias)

    return last_fully_connected

# %% [markdown]
# ## Create the objects for the model

# %%
model_output = my_conv_neural_net(x_input)
test_model_ouput = my_conv_neural_net(eval_input)

# %%
loss = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits = model_output, labels = y_target))

# %%
prediction = tf.nn.softmax(model_output)
test_prediction = tf.nn.softmax(test_model_ouput)

def get_accuracy(logits,targets):
    batch_predictions = np.argmax(logits, axis=1)
    num_corrects = np.sum(np.equal(batch_predictions, targets))
    return 100.0*num_corrects/batch_predictions.shape[0]

# %% [markdown]
# # Train the model

# %%
my_optim = tf.train.AdamOptimizer(learning_rate=learning_rate,beta1=beta1,beta2=beta2)#Adam
train_step = my_optim.minimize(loss)

# %%
#### Save the model
saver = tf.train.Saver()

# %%
init = tf.global_variables_initializer()
session.run(init)

# %%
train_loss = []
train_acc = []
test_acc = []
i_vals = []

i = 0
temp_train_loss = 1.0
temp_train_acc = 0.0
temp_test_acc = 0.0
while (i < epochs) and (temp_train_loss > 0.001):
    rand_idx = np.random.choice(len(train_xdata), size=batch_size)
    rand_x = train_xdata[rand_idx]


    rand_y = train_labels[rand_idx]
    train_dict = {x_input: rand_x, y_target: rand_y}
    session.run(train_step, feed_dict=train_dict)
    temp_train_loss, temp_train_preds = session.run([loss,prediction], feed_dict = train_dict)
    temp_train_acc = get_accuracy(temp_train_preds, rand_y)

    ## For saving
    saved_path = saver.save(session, 'nn_model/my_model', global_step=i+1)

    if ((i+1)%eval_every == 0)or(temp_train_loss <= 0.001)or((temp_train_acc >= 99.0)and(temp_test_acc >= 99.0)):
        rand_idx_eval = np.random.choice(len(test_xdata), size=evaluation_size)
        rand_x_eval = test_xdata[rand_idx_eval]
        
        rand_y_eval = test_labels[rand_idx_eval]
        test_dict = {eval_input: rand_x_eval, eval_target: rand_y_eval}

        temp_test_preds = session.run(test_prediction, feed_dict = test_dict)
        temp_test_acc = get_accuracy(temp_test_preds, rand_y_eval)

        i_vals.append(i+1)
        train_loss.append(temp_train_loss)
        train_acc.append(temp_train_acc)
        test_acc.append(temp_test_acc)

        acc_and_loss = [(i+1), temp_train_loss, temp_train_acc, temp_test_acc]
        acc_and_loss = [np.round(x,3) for x in acc_and_loss]

        print("Epoch {}. Train loss: {:.4f}. Train acc: {:.2f}, Val acc: {:.1f}".format(*acc_and_loss))
    i = i + 1
# Out:
# Epoch 5. Train loss: 0.6930. Train acc: 49.90, Val acc: 50.0
# WARNING:tensorflow:From c:\Users\mary9\anaconda3\envs\cv_lab\lib\site-packages\tensorflow\python\training\saver.py:1067: remove_checkpoint (from tensorflow.python.checkpoint.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# Epoch 10. Train loss: 0.6890. Train acc: 53.90, Val acc: 43.0
# Epoch 15. Train loss: 0.6800. Train acc: 55.80, Val acc: 58.0
# Epoch 20. Train loss: 0.6670. Train acc: 61.00, Val acc: 69.0
# Epoch 25. Train loss: 0.6450. Train acc: 62.60, Val acc: 66.0
# Epoch 30. Train loss: 0.6700. Train acc: 59.70, Val acc: 58.0
# Epoch 35. Train loss: 0.6480. Train acc: 61.40, Val acc: 57.0
# Epoch 40. Train loss: 0.6550. Train acc: 60.30, Val acc: 61.0
# Epoch 45. Train loss: 0.6350. Train acc: 62.90, Val acc: 66.0
# Epoch 50. Train loss: 0.6230. Train acc: 64.60, Val acc: 59.0
# Epoch 55. Train loss: 0.6440. Train acc: 62.80, Val acc: 57.0
# Epoch 60. Train loss: 0.6100. Train acc: 66.70, Val acc: 58.0
# Epoch 65. Train loss: 0.6320. Train acc: 62.50, Val acc: 48.0
# Epoch 70. Train loss: 0.6200. Train acc: 65.20, Val acc: 60.0
# Epoch 75. Train loss: 0.5910. Train acc: 69.20, Val acc: 66.0
# Epoch 80. Train loss: 0.5940. Train acc: 69.90, Val acc: 63.0
# Epoch 85. Train loss: 0.6000. Train acc: 68.00, Val acc: 61.0
# Epoch 90. Train loss: 0.5930. Train acc: 67.50, Val acc: 58.0
# Epoch 95. Train loss: 0.6020. Train acc: 68.50, Val acc: 65.0
# Epoch 100. Train loss: 0.5470. Train acc: 72.00, Val acc: 62.0
# Epoch 105. Train loss: 0.5570. Train acc: 72.80, Val acc: 63.0
# Epoch 110. Train loss: 0.5440. Train acc: 71.10, Val acc: 54.0
# Epoch 115. Train loss: 0.5740. Train acc: 69.10, Val acc: 55.0
# Epoch 120. Train loss: 0.5370. Train acc: 71.30, Val acc: 54.0
# Epoch 125. Train loss: 0.5250. Train acc: 75.00, Val acc: 67.0
# Epoch 130. Train loss: 0.5230. Train acc: 76.80, Val acc: 57.0
# Epoch 135. Train loss: 0.5640. Train acc: 70.20, Val acc: 61.0
# Epoch 140. Train loss: 0.5430. Train acc: 70.60, Val acc: 54.0
# Epoch 145. Train loss: 0.4800. Train acc: 79.60, Val acc: 65.0
# Epoch 150. Train loss: 0.4520. Train acc: 81.10, Val acc: 54.0
# Epoch 155. Train loss: 0.9220. Train acc: 56.00, Val acc: 46.0
# Epoch 160. Train loss: 0.4970. Train acc: 79.80, Val acc: 62.0
# Epoch 165. Train loss: 0.5430. Train acc: 76.40, Val acc: 55.0
# Epoch 170. Train loss: 0.5000. Train acc: 79.90, Val acc: 66.0
# Epoch 175. Train loss: 0.5080. Train acc: 74.50, Val acc: 53.0
# Epoch 180. Train loss: 0.4640. Train acc: 78.70, Val acc: 62.0
# Epoch 185. Train loss: 0.5430. Train acc: 73.60, Val acc: 63.0
# Epoch 190. Train loss: 0.4570. Train acc: 82.00, Val acc: 57.0
# Epoch 195. Train loss: 0.4860. Train acc: 77.60, Val acc: 60.0
# Epoch 200. Train loss: 0.4870. Train acc: 75.70, Val acc: 57.0
# Epoch 205. Train loss: 0.4480. Train acc: 79.80, Val acc: 59.0
# Epoch 210. Train loss: 0.4370. Train acc: 80.00, Val acc: 57.0
# Epoch 215. Train loss: 0.3900. Train acc: 82.20, Val acc: 66.0
# Epoch 220. Train loss: 0.4860. Train acc: 75.30, Val acc: 64.0
# Epoch 225. Train loss: 0.5270. Train acc: 72.90, Val acc: 65.0
# Epoch 230. Train loss: 0.4090. Train acc: 81.70, Val acc: 67.0
# Epoch 235. Train loss: 0.3990. Train acc: 82.40, Val acc: 62.0
# Epoch 240. Train loss: 0.3850. Train acc: 83.10, Val acc: 64.0
# Epoch 245. Train loss: 0.3770. Train acc: 85.10, Val acc: 65.0
# Epoch 250. Train loss: 0.3710. Train acc: 83.90, Val acc: 53.0
# Epoch 255. Train loss: 0.4920. Train acc: 76.20, Val acc: 60.0
# Epoch 260. Train loss: 0.4040. Train acc: 80.50, Val acc: 63.0
# Epoch 265. Train loss: 0.3740. Train acc: 83.40, Val acc: 61.0
# Epoch 270. Train loss: 0.3900. Train acc: 82.20, Val acc: 51.0
# Epoch 275. Train loss: 0.2940. Train acc: 89.30, Val acc: 56.0
# Epoch 280. Train loss: 0.3090. Train acc: 86.80, Val acc: 60.0
# Epoch 285. Train loss: 0.3090. Train acc: 86.20, Val acc: 64.0
# Epoch 290. Train loss: 0.2900. Train acc: 88.70, Val acc: 60.0
# Epoch 295. Train loss: 0.3910. Train acc: 81.60, Val acc: 64.0
# Epoch 300. Train loss: 0.3860. Train acc: 81.90, Val acc: 58.0
# Epoch 305. Train loss: 0.3230. Train acc: 86.90, Val acc: 66.0
# Epoch 310. Train loss: 0.2750. Train acc: 89.70, Val acc: 62.0
# Epoch 315. Train loss: 0.2360. Train acc: 92.10, Val acc: 61.0
# Epoch 320. Train loss: 0.3740. Train acc: 82.00, Val acc: 60.0
# Epoch 325. Train loss: 0.4080. Train acc: 82.60, Val acc: 62.0
# Epoch 330. Train loss: 0.3770. Train acc: 84.50, Val acc: 62.0
# Epoch 335. Train loss: 0.2880. Train acc: 88.80, Val acc: 58.0
# Epoch 340. Train loss: 0.2520. Train acc: 90.90, Val acc: 64.0
# Epoch 345. Train loss: 0.2820. Train acc: 89.30, Val acc: 62.0
# Epoch 350. Train loss: 0.3690. Train acc: 83.30, Val acc: 60.0
# Epoch 355. Train loss: 0.2980. Train acc: 87.50, Val acc: 58.0
# Epoch 360. Train loss: 0.2250. Train acc: 92.40, Val acc: 65.0
# Epoch 365. Train loss: 0.2870. Train acc: 88.10, Val acc: 58.0
# Epoch 370. Train loss: 0.2030. Train acc: 93.80, Val acc: 61.0
# Epoch 375. Train loss: 0.2670. Train acc: 87.30, Val acc: 65.0
# Epoch 380. Train loss: 0.1980. Train acc: 92.70, Val acc: 58.0
# Epoch 385. Train loss: 0.1570. Train acc: 95.30, Val acc: 50.0
# Epoch 390. Train loss: 0.1480. Train acc: 95.60, Val acc: 61.0
# Epoch 395. Train loss: 0.1580. Train acc: 93.50, Val acc: 52.0
# Epoch 400. Train loss: 0.1190. Train acc: 97.00, Val acc: 53.0
# Epoch 405. Train loss: 1.7780. Train acc: 58.80, Val acc: 58.0
# Epoch 410. Train loss: 0.6300. Train acc: 53.20, Val acc: 57.0
# Epoch 415. Train loss: 0.5900. Train acc: 51.20, Val acc: 56.0
# Epoch 420. Train loss: 0.5590. Train acc: 71.10, Val acc: 63.0
# Epoch 425. Train loss: 0.4390. Train acc: 81.90, Val acc: 58.0
# Epoch 430. Train loss: 0.3880. Train acc: 81.10, Val acc: 65.0
# Epoch 435. Train loss: 0.2930. Train acc: 90.70, Val acc: 56.0
# Epoch 440. Train loss: 0.3940. Train acc: 79.90, Val acc: 60.0
# Epoch 445. Train loss: 0.3790. Train acc: 81.10, Val acc: 58.0
# Epoch 450. Train loss: 0.2560. Train acc: 89.90, Val acc: 62.0
# Epoch 455. Train loss: 0.2130. Train acc: 92.90, Val acc: 63.0
# Epoch 460. Train loss: 0.2560. Train acc: 89.10, Val acc: 52.0
# Epoch 465. Train loss: 0.2730. Train acc: 88.60, Val acc: 74.0
# Epoch 470. Train loss: 0.2570. Train acc: 89.00, Val acc: 59.0
# Epoch 475. Train loss: 0.1850. Train acc: 92.20, Val acc: 54.0
# Epoch 480. Train loss: 0.1540. Train acc: 94.70, Val acc: 60.0
# Epoch 485. Train loss: 0.1620. Train acc: 95.00, Val acc: 64.0
# Epoch 490. Train loss: 0.1050. Train acc: 96.50, Val acc: 67.0
# Epoch 495. Train loss: 0.1020. Train acc: 96.50, Val acc: 58.0
# Epoch 500. Train loss: 0.1050. Train acc: 97.30, Val acc: 59.0
# Epoch 505. Train loss: 0.1700. Train acc: 92.10, Val acc: 63.0
# Epoch 510. Train loss: 0.3880. Train acc: 84.10, Val acc: 55.0
# Epoch 515. Train loss: 0.3020. Train acc: 88.50, Val acc: 56.0
# Epoch 520. Train loss: 0.2700. Train acc: 88.70, Val acc: 60.0
# Epoch 525. Train loss: 0.1950. Train acc: 94.10, Val acc: 57.0
# Epoch 530. Train loss: 0.1920. Train acc: 92.80, Val acc: 62.0
# Epoch 535. Train loss: 0.1360. Train acc: 96.00, Val acc: 60.0
# Epoch 540. Train loss: 0.1310. Train acc: 95.50, Val acc: 52.0
# Epoch 545. Train loss: 0.4040. Train acc: 82.30, Val acc: 62.0
# Epoch 550. Train loss: 0.1630. Train acc: 93.90, Val acc: 60.0
# Epoch 555. Train loss: 0.2780. Train acc: 87.90, Val acc: 57.0
# Epoch 560. Train loss: 0.2600. Train acc: 88.60, Val acc: 54.0
# Epoch 565. Train loss: 0.1640. Train acc: 93.90, Val acc: 61.0
# Epoch 570. Train loss: 0.1630. Train acc: 94.30, Val acc: 68.0
# Epoch 575. Train loss: 0.1810. Train acc: 91.70, Val acc: 63.0
# Epoch 580. Train loss: 0.1380. Train acc: 95.50, Val acc: 62.0
# Epoch 585. Train loss: 0.1030. Train acc: 96.40, Val acc: 63.0
# Epoch 590. Train loss: 0.0880. Train acc: 97.60, Val acc: 61.0
# Epoch 595. Train loss: 0.0800. Train acc: 97.50, Val acc: 62.0
# Epoch 600. Train loss: 0.0850. Train acc: 97.90, Val acc: 60.0
# Epoch 605. Train loss: 0.0630. Train acc: 98.60, Val acc: 66.0
# Epoch 610. Train loss: 0.0690. Train acc: 97.90, Val acc: 67.0
# Epoch 615. Train loss: 0.1040. Train acc: 96.20, Val acc: 50.0
# Epoch 620. Train loss: 0.0530. Train acc: 98.40, Val acc: 49.0
# Epoch 625. Train loss: 0.0810. Train acc: 96.80, Val acc: 59.0
# Epoch 630. Train loss: 0.0630. Train acc: 97.90, Val acc: 55.0
# Epoch 635. Train loss: 0.0380. Train acc: 99.40, Val acc: 68.0
# Epoch 640. Train loss: 0.0490. Train acc: 98.00, Val acc: 55.0
# Epoch 645. Train loss: 0.0340. Train acc: 99.00, Val acc: 58.0
# Epoch 650. Train loss: 0.0390. Train acc: 98.70, Val acc: 62.0
# Epoch 655. Train loss: 0.0180. Train acc: 100.00, Val acc: 55.0
# Epoch 660. Train loss: 0.0290. Train acc: 99.50, Val acc: 61.0
# Epoch 665. Train loss: 0.0300. Train acc: 99.20, Val acc: 62.0
# Epoch 670. Train loss: 0.0290. Train acc: 99.40, Val acc: 55.0
# Epoch 675. Train loss: 0.0320. Train acc: 98.90, Val acc: 59.0
# Epoch 680. Train loss: 0.0270. Train acc: 99.10, Val acc: 61.0
# Epoch 685. Train loss: 0.0260. Train acc: 99.40, Val acc: 69.0
# Epoch 690. Train loss: 0.0880. Train acc: 95.70, Val acc: 53.0
# Epoch 695. Train loss: 0.7940. Train acc: 75.70, Val acc: 52.0
# Epoch 700. Train loss: 0.6170. Train acc: 65.70, Val acc: 53.0
# Epoch 705. Train loss: 0.5490. Train acc: 73.80, Val acc: 56.0
# Epoch 710. Train loss: 0.6870. Train acc: 60.90, Val acc: 52.0
# Epoch 715. Train loss: 0.6410. Train acc: 64.70, Val acc: 53.0
# Epoch 720. Train loss: 0.5050. Train acc: 74.70, Val acc: 53.0
# Epoch 725. Train loss: 0.4300. Train acc: 77.20, Val acc: 54.0
# Epoch 730. Train loss: 0.4390. Train acc: 78.10, Val acc: 56.0
# Epoch 735. Train loss: 0.3320. Train acc: 85.60, Val acc: 66.0
# Epoch 740. Train loss: 0.3820. Train acc: 80.30, Val acc: 59.0
# Epoch 745. Train loss: 0.3000. Train acc: 87.90, Val acc: 59.0
# Epoch 750. Train loss: 0.2660. Train acc: 91.50, Val acc: 63.0
# Epoch 755. Train loss: 0.2530. Train acc: 91.20, Val acc: 68.0
# Epoch 760. Train loss: 0.4630. Train acc: 76.40, Val acc: 51.0
# Epoch 765. Train loss: 0.2710. Train acc: 90.20, Val acc: 52.0
# Epoch 770. Train loss: 0.2300. Train acc: 92.20, Val acc: 60.0
# Epoch 775. Train loss: 0.2340. Train acc: 92.80, Val acc: 56.0
# Epoch 780. Train loss: 0.3070. Train acc: 85.60, Val acc: 57.0
# Epoch 785. Train loss: 0.3210. Train acc: 84.70, Val acc: 57.0
# Epoch 790. Train loss: 0.2070. Train acc: 92.00, Val acc: 53.0
# Epoch 795. Train loss: 0.2800. Train acc: 86.70, Val acc: 56.0
# Epoch 800. Train loss: 0.2080. Train acc: 93.50, Val acc: 54.0
# Epoch 805. Train loss: 0.1470. Train acc: 96.40, Val acc: 61.0
# Epoch 810. Train loss: 0.1420. Train acc: 96.50, Val acc: 57.0
# Epoch 815. Train loss: 0.1220. Train acc: 96.60, Val acc: 52.0
# Epoch 820. Train loss: 0.1190. Train acc: 97.00, Val acc: 61.0
# Epoch 825. Train loss: 0.1240. Train acc: 97.30, Val acc: 62.0
# Epoch 830. Train loss: 0.0890. Train acc: 98.70, Val acc: 61.0
# Epoch 835. Train loss: 0.0960. Train acc: 98.00, Val acc: 62.0
# Epoch 840. Train loss: 0.1140. Train acc: 96.40, Val acc: 59.0
# Epoch 845. Train loss: 0.7410. Train acc: 73.50, Val acc: 54.0
# Epoch 850. Train loss: 0.4870. Train acc: 74.60, Val acc: 54.0
# Epoch 855. Train loss: 0.5700. Train acc: 69.30, Val acc: 54.0
# Epoch 860. Train loss: 0.4690. Train acc: 77.70, Val acc: 54.0
# Epoch 865. Train loss: 0.4180. Train acc: 80.40, Val acc: 61.0
# Epoch 870. Train loss: 0.3820. Train acc: 83.00, Val acc: 49.0
# Epoch 875. Train loss: 0.3290. Train acc: 86.30, Val acc: 64.0
# Epoch 880. Train loss: 0.3230. Train acc: 88.60, Val acc: 66.0
# Epoch 885. Train loss: 0.2910. Train acc: 89.60, Val acc: 62.0
# Epoch 890. Train loss: 0.2970. Train acc: 89.40, Val acc: 59.0
# Epoch 895. Train loss: 0.4190. Train acc: 78.60, Val acc: 61.0
# Epoch 900. Train loss: 0.2410. Train acc: 92.30, Val acc: 62.0
# Epoch 905. Train loss: 0.2710. Train acc: 88.80, Val acc: 63.0
# Epoch 910. Train loss: 0.2420. Train acc: 91.10, Val acc: 57.0
# Epoch 915. Train loss: 0.2000. Train acc: 94.30, Val acc: 59.0
# Epoch 920. Train loss: 0.4120. Train acc: 78.20, Val acc: 53.0
# Epoch 925. Train loss: 0.2670. Train acc: 87.60, Val acc: 59.0
# Epoch 930. Train loss: 0.3040. Train acc: 86.20, Val acc: 59.0
# Epoch 935. Train loss: 0.2060. Train acc: 92.50, Val acc: 56.0
# Epoch 940. Train loss: 0.2540. Train acc: 88.30, Val acc: 63.0
# Epoch 945. Train loss: 0.1590. Train acc: 95.70, Val acc: 62.0
# Epoch 950. Train loss: 0.1830. Train acc: 94.50, Val acc: 57.0
# Epoch 955. Train loss: 0.1720. Train acc: 95.40, Val acc: 62.0
# Epoch 960. Train loss: 0.1440. Train acc: 96.20, Val acc: 66.0
# Epoch 965. Train loss: 0.1440. Train acc: 96.00, Val acc: 61.0
# Epoch 970. Train loss: 0.1830. Train acc: 93.80, Val acc: 66.0
# Epoch 975. Train loss: 0.2620. Train acc: 87.60, Val acc: 61.0
# Epoch 980. Train loss: 0.2940. Train acc: 84.70, Val acc: 57.0
# Epoch 985. Train loss: 0.1960. Train acc: 91.90, Val acc: 62.0
# Epoch 990. Train loss: 0.3610. Train acc: 82.70, Val acc: 63.0
# Epoch 995. Train loss: 0.1950. Train acc: 92.90, Val acc: 51.0
# Epoch 1000. Train loss: 0.1290. Train acc: 95.60, Val acc: 64.0
# Epoch 1005. Train loss: 0.1260. Train acc: 96.30, Val acc: 63.0
# Epoch 1010. Train loss: 0.1140. Train acc: 96.80, Val acc: 59.0
# Epoch 1015. Train loss: 0.1050. Train acc: 96.60, Val acc: 63.0
# Epoch 1020. Train loss: 0.1260. Train acc: 96.70, Val acc: 55.0
# Epoch 1025. Train loss: 0.0810. Train acc: 98.00, Val acc: 62.0
# Epoch 1030. Train loss: 0.0940. Train acc: 97.90, Val acc: 64.0
# Epoch 1035. Train loss: 0.0950. Train acc: 96.80, Val acc: 65.0
# Epoch 1040. Train loss: 0.0810. Train acc: 97.70, Val acc: 68.0
# Epoch 1045. Train loss: 0.0930. Train acc: 97.90, Val acc: 53.0
# Epoch 1050. Train loss: 0.1400. Train acc: 94.80, Val acc: 54.0
# Epoch 1055. Train loss: 0.0790. Train acc: 97.80, Val acc: 61.0
# Epoch 1060. Train loss: 0.0820. Train acc: 98.30, Val acc: 63.0
# Epoch 1065. Train loss: 0.0660. Train acc: 98.80, Val acc: 65.0
# Epoch 1070. Train loss: 0.0590. Train acc: 99.10, Val acc: 48.0
# Epoch 1075. Train loss: 0.0670. Train acc: 98.60, Val acc: 65.0
# Epoch 1080. Train loss: 0.0610. Train acc: 98.80, Val acc: 64.0
# Epoch 1085. Train loss: 0.0540. Train acc: 98.80, Val acc: 65.0
# Epoch 1090. Train loss: 0.0610. Train acc: 98.60, Val acc: 64.0
# Epoch 1095. Train loss: 0.0620. Train acc: 99.10, Val acc: 55.0
# Epoch 1100. Train loss: 0.0800. Train acc: 97.80, Val acc: 53.0
# Epoch 1105. Train loss: 0.0510. Train acc: 98.70, Val acc: 55.0
# Epoch 1110. Train loss: 0.0670. Train acc: 99.00, Val acc: 51.0
# Epoch 1115. Train loss: 0.0640. Train acc: 97.70, Val acc: 59.0
# Epoch 1120. Train loss: 0.0740. Train acc: 97.20, Val acc: 58.0
# Epoch 1125. Train loss: 0.0490. Train acc: 99.10, Val acc: 46.0
# Epoch 1130. Train loss: 0.0290. Train acc: 99.90, Val acc: 59.0
# Epoch 1135. Train loss: 0.0520. Train acc: 98.80, Val acc: 63.0
# Epoch 1140. Train loss: 0.0220. Train acc: 100.00, Val acc: 61.0
# Epoch 1145. Train loss: 0.0350. Train acc: 99.20, Val acc: 64.0
# Epoch 1150. Train loss: 0.0300. Train acc: 99.40, Val acc: 60.0
# Epoch 1155. Train loss: 0.0420. Train acc: 99.60, Val acc: 59.0
# Epoch 1160. Train loss: 0.0250. Train acc: 99.70, Val acc: 60.0
# Epoch 1165. Train loss: 0.0230. Train acc: 99.70, Val acc: 61.0
# Epoch 1170. Train loss: 0.0230. Train acc: 99.80, Val acc: 64.0
# Epoch 1175. Train loss: 0.0280. Train acc: 99.80, Val acc: 66.0
# Epoch 1180. Train loss: 0.0160. Train acc: 100.00, Val acc: 55.0
# Epoch 1185. Train loss: 0.0140. Train acc: 100.00, Val acc: 64.0
# Epoch 1190. Train loss: 0.0170. Train acc: 99.90, Val acc: 57.0
# Epoch 1195. Train loss: 0.0160. Train acc: 99.90, Val acc: 60.0
# Epoch 1200. Train loss: 0.0180. Train acc: 99.70, Val acc: 56.0
# Epoch 1205. Train loss: 0.0200. Train acc: 99.90, Val acc: 60.0
# Epoch 1210. Train loss: 0.0120. Train acc: 100.00, Val acc: 53.0
# Epoch 1215. Train loss: 0.0160. Train acc: 99.80, Val acc: 63.0
# Epoch 1220. Train loss: 0.0180. Train acc: 99.90, Val acc: 54.0
# Epoch 1225. Train loss: 0.0220. Train acc: 99.60, Val acc: 53.0
# Epoch 1230. Train loss: 0.0150. Train acc: 99.80, Val acc: 56.0
# Epoch 1235. Train loss: 0.0100. Train acc: 100.00, Val acc: 63.0
# Epoch 1240. Train loss: 9.4750. Train acc: 55.50, Val acc: 52.0
# Epoch 1245. Train loss: 0.8860. Train acc: 59.30, Val acc: 55.0
# Epoch 1250. Train loss: 0.6860. Train acc: 52.60, Val acc: 50.0
# Epoch 1255. Train loss: 0.6640. Train acc: 59.70, Val acc: 54.0
# Epoch 1260. Train loss: 0.6450. Train acc: 68.40, Val acc: 47.0
# Epoch 1265. Train loss: 0.6520. Train acc: 64.90, Val acc: 59.0
# Epoch 1270. Train loss: 0.6380. Train acc: 66.00, Val acc: 56.0
# Epoch 1275. Train loss: 0.6120. Train acc: 67.70, Val acc: 66.0
# Epoch 1280. Train loss: 0.5970. Train acc: 69.30, Val acc: 53.0
# Epoch 1285. Train loss: 0.6330. Train acc: 63.70, Val acc: 55.0
# Epoch 1290. Train loss: 0.6820. Train acc: 60.50, Val acc: 63.0
# Epoch 1295. Train loss: 0.6240. Train acc: 63.90, Val acc: 49.0
# Epoch 1300. Train loss: 0.6090. Train acc: 68.40, Val acc: 60.0
# Epoch 1305. Train loss: 0.6000. Train acc: 69.40, Val acc: 56.0
# Epoch 1310. Train loss: 0.5880. Train acc: 70.80, Val acc: 59.0
# Epoch 1315. Train loss: 0.5740. Train acc: 72.60, Val acc: 59.0
# Epoch 1320. Train loss: 0.5590. Train acc: 73.70, Val acc: 62.0
# Epoch 1325. Train loss: 0.5750. Train acc: 69.30, Val acc: 68.0
# Epoch 1330. Train loss: 0.5440. Train acc: 73.90, Val acc: 65.0
# Epoch 1335. Train loss: 0.6230. Train acc: 64.80, Val acc: 57.0
# Epoch 1340. Train loss: 0.4850. Train acc: 79.10, Val acc: 59.0
# Epoch 1345. Train loss: 0.5400. Train acc: 72.40, Val acc: 62.0
# Epoch 1350. Train loss: 0.6360. Train acc: 65.10, Val acc: 61.0
# Epoch 1355. Train loss: 0.6480. Train acc: 67.00, Val acc: 54.0
# Epoch 1360. Train loss: 0.6280. Train acc: 65.10, Val acc: 43.0
# Epoch 1365. Train loss: 0.6200. Train acc: 64.90, Val acc: 62.0
# Epoch 1370. Train loss: 0.5780. Train acc: 69.80, Val acc: 60.0
# Epoch 1375. Train loss: 0.5600. Train acc: 71.60, Val acc: 61.0
# Epoch 1380. Train loss: 0.5600. Train acc: 70.40, Val acc: 62.0
# Epoch 1385. Train loss: 0.5370. Train acc: 73.70, Val acc: 61.0
# Epoch 1390. Train loss: 0.5520. Train acc: 70.30, Val acc: 60.0
# Epoch 1395. Train loss: 0.5810. Train acc: 67.80, Val acc: 64.0
# Epoch 1400. Train loss: 0.5190. Train acc: 76.50, Val acc: 57.0
# Epoch 1405. Train loss: 0.5530. Train acc: 72.00, Val acc: 46.0
# Epoch 1410. Train loss: 0.4900. Train acc: 79.60, Val acc: 64.0
# Epoch 1415. Train loss: 0.4970. Train acc: 76.60, Val acc: 58.0
# Epoch 1420. Train loss: 0.5070. Train acc: 75.10, Val acc: 59.0
# Epoch 1425. Train loss: 0.5200. Train acc: 75.70, Val acc: 57.0
# Epoch 1430. Train loss: 0.4590. Train acc: 81.80, Val acc: 52.0
# Epoch 1435. Train loss: 0.4830. Train acc: 79.80, Val acc: 54.0
# Epoch 1440. Train loss: 0.5570. Train acc: 71.00, Val acc: 51.0
# Epoch 1445. Train loss: 0.4700. Train acc: 80.10, Val acc: 59.0
# Epoch 1450. Train loss: 0.4360. Train acc: 83.00, Val acc: 60.0
# Epoch 1455. Train loss: 0.4480. Train acc: 79.60, Val acc: 63.0
# Epoch 1460. Train loss: 0.4180. Train acc: 83.40, Val acc: 59.0
# Epoch 1465. Train loss: 0.4000. Train acc: 84.40, Val acc: 55.0
# Epoch 1470. Train loss: 0.4080. Train acc: 83.20, Val acc: 55.0
# Epoch 1475. Train loss: 0.5960. Train acc: 69.30, Val acc: 52.0
# Epoch 1480. Train loss: 0.4010. Train acc: 84.30, Val acc: 49.0
# Epoch 1485. Train loss: 0.3870. Train acc: 85.00, Val acc: 51.0
# Epoch 1490. Train loss: 0.4240. Train acc: 81.20, Val acc: 63.0
# Epoch 1495. Train loss: 0.4480. Train acc: 79.10, Val acc: 51.0
# Epoch 1500. Train loss: 0.3530. Train acc: 85.70, Val acc: 61.0
# Epoch 1505. Train loss: 0.3940. Train acc: 83.50, Val acc: 50.0
# Epoch 1510. Train loss: 0.4010. Train acc: 82.80, Val acc: 57.0
# Epoch 1515. Train loss: 0.3450. Train acc: 86.80, Val acc: 54.0
# Epoch 1520. Train loss: 0.4490. Train acc: 79.00, Val acc: 58.0
# Epoch 1525. Train loss: 0.3650. Train acc: 84.10, Val acc: 54.0
# Epoch 1530. Train loss: 0.3740. Train acc: 84.00, Val acc: 54.0
# Epoch 1535. Train loss: 0.3260. Train acc: 88.80, Val acc: 63.0
# Epoch 1540. Train loss: 0.3360. Train acc: 86.30, Val acc: 57.0
# Epoch 1545. Train loss: 0.5190. Train acc: 74.90, Val acc: 57.0
# Epoch 1550. Train loss: 0.3930. Train acc: 81.90, Val acc: 59.0
# Epoch 1555. Train loss: 0.3580. Train acc: 84.80, Val acc: 56.0
# Epoch 1560. Train loss: 0.3960. Train acc: 83.30, Val acc: 52.0
# Epoch 1565. Train loss: 0.3490. Train acc: 86.60, Val acc: 59.0
# Epoch 1570. Train loss: 0.3160. Train acc: 88.20, Val acc: 55.0
# Epoch 1575. Train loss: 0.3360. Train acc: 88.00, Val acc: 54.0
# Epoch 1580. Train loss: 0.3040. Train acc: 90.00, Val acc: 53.0
# Epoch 1585. Train loss: 0.3350. Train acc: 87.40, Val acc: 53.0
# Epoch 1590. Train loss: 0.3770. Train acc: 84.10, Val acc: 66.0
# Epoch 1595. Train loss: 0.4540. Train acc: 78.30, Val acc: 45.0
# Epoch 1600. Train loss: 0.3860. Train acc: 83.90, Val acc: 60.0
# Epoch 1605. Train loss: 0.2900. Train acc: 89.20, Val acc: 56.0
# Epoch 1610. Train loss: 0.3290. Train acc: 87.80, Val acc: 58.0
# Epoch 1615. Train loss: 0.3560. Train acc: 86.60, Val acc: 60.0
# Epoch 1620. Train loss: 0.3010. Train acc: 88.30, Val acc: 58.0
# Epoch 1625. Train loss: 0.3330. Train acc: 88.40, Val acc: 55.0
# Epoch 1630. Train loss: 0.2850. Train acc: 90.70, Val acc: 60.0
# Epoch 1635. Train loss: 0.3520. Train acc: 86.70, Val acc: 50.0
# Epoch 1640. Train loss: 0.3190. Train acc: 88.50, Val acc: 64.0
# Epoch 1645. Train loss: 0.3490. Train acc: 86.10, Val acc: 62.0
# Epoch 1650. Train loss: 0.3580. Train acc: 86.80, Val acc: 56.0
# Epoch 1655. Train loss: 0.3070. Train acc: 89.10, Val acc: 50.0
# Epoch 1660. Train loss: 0.3610. Train acc: 85.80, Val acc: 61.0
# Epoch 1665. Train loss: 0.2640. Train acc: 92.10, Val acc: 54.0
# Epoch 1670. Train loss: 0.3970. Train acc: 82.70, Val acc: 58.0
# Epoch 1675. Train loss: 0.3060. Train acc: 89.80, Val acc: 65.0
# Epoch 1680. Train loss: 0.3610. Train acc: 83.90, Val acc: 51.0
# Epoch 1685. Train loss: 0.2730. Train acc: 89.50, Val acc: 67.0
# Epoch 1690. Train loss: 0.2540. Train acc: 91.70, Val acc: 57.0
# Epoch 1695. Train loss: 0.2630. Train acc: 91.30, Val acc: 48.0
# Epoch 1700. Train loss: 0.2480. Train acc: 91.00, Val acc: 57.0
# Epoch 1705. Train loss: 0.2460. Train acc: 91.80, Val acc: 57.0
# Epoch 1710. Train loss: 0.2340. Train acc: 92.30, Val acc: 56.0
# Epoch 1715. Train loss: 0.2390. Train acc: 92.40, Val acc: 55.0
# Epoch 1720. Train loss: 0.2460. Train acc: 91.40, Val acc: 56.0
# Epoch 1725. Train loss: 0.2610. Train acc: 91.10, Val acc: 53.0
# Epoch 1730. Train loss: 0.2690. Train acc: 88.80, Val acc: 57.0
# Epoch 1735. Train loss: 0.2520. Train acc: 92.10, Val acc: 60.0
# Epoch 1740. Train loss: 0.2960. Train acc: 88.00, Val acc: 59.0
# Epoch 1745. Train loss: 0.3370. Train acc: 84.80, Val acc: 58.0
# Epoch 1750. Train loss: 0.2450. Train acc: 92.30, Val acc: 55.0
# Epoch 1755. Train loss: 0.4210. Train acc: 80.30, Val acc: 55.0
# Epoch 1760. Train loss: 0.2400. Train acc: 91.90, Val acc: 62.0
# Epoch 1765. Train loss: 0.2310. Train acc: 93.20, Val acc: 54.0
# Epoch 1770. Train loss: 0.2660. Train acc: 91.00, Val acc: 62.0
# Epoch 1775. Train loss: 0.2860. Train acc: 88.00, Val acc: 54.0
# Epoch 1780. Train loss: 0.3000. Train acc: 87.60, Val acc: 54.0
# Epoch 1785. Train loss: 0.3050. Train acc: 87.60, Val acc: 55.0
# Epoch 1790. Train loss: 0.2680. Train acc: 89.40, Val acc: 55.0
# Epoch 1795. Train loss: 0.2660. Train acc: 91.40, Val acc: 65.0
# Epoch 1800. Train loss: 0.2270. Train acc: 94.30, Val acc: 58.0
# Epoch 1805. Train loss: 0.2380. Train acc: 93.80, Val acc: 54.0
# Epoch 1810. Train loss: 0.2020. Train acc: 94.30, Val acc: 67.0
# Epoch 1815. Train loss: 0.2280. Train acc: 93.30, Val acc: 61.0
# Epoch 1820. Train loss: 0.2150. Train acc: 95.10, Val acc: 53.0
# Epoch 1825. Train loss: 0.2040. Train acc: 93.70, Val acc: 55.0
# Epoch 1830. Train loss: 0.1860. Train acc: 94.90, Val acc: 47.0
# Epoch 1835. Train loss: 0.2250. Train acc: 93.20, Val acc: 66.0
# Epoch 1840. Train loss: 0.2230. Train acc: 92.70, Val acc: 56.0
# Epoch 1845. Train loss: 0.3990. Train acc: 81.90, Val acc: 54.0
# Epoch 1850. Train loss: 1.0190. Train acc: 62.50, Val acc: 56.0
# Epoch 1855. Train loss: 0.9280. Train acc: 62.30, Val acc: 52.0
# Epoch 1860. Train loss: 0.6780. Train acc: 69.10, Val acc: 55.0
# Epoch 1865. Train loss: 0.3290. Train acc: 87.00, Val acc: 57.0
# Epoch 1870. Train loss: 0.2630. Train acc: 92.60, Val acc: 61.0
# Epoch 1875. Train loss: 0.3090. Train acc: 88.50, Val acc: 60.0
# Epoch 1880. Train loss: 0.2550. Train acc: 92.40, Val acc: 57.0
# Epoch 1885. Train loss: 0.2480. Train acc: 93.60, Val acc: 55.0
# Epoch 1890. Train loss: 0.2710. Train acc: 92.00, Val acc: 58.0
# Epoch 1895. Train loss: 0.2150. Train acc: 94.80, Val acc: 68.0
# Epoch 1900. Train loss: 0.2000. Train acc: 95.40, Val acc: 64.0
# Epoch 1905. Train loss: 0.1850. Train acc: 95.70, Val acc: 47.0
# Epoch 1910. Train loss: 0.2060. Train acc: 94.50, Val acc: 52.0
# Epoch 1915. Train loss: 0.1640. Train acc: 96.50, Val acc: 58.0
# Epoch 1920. Train loss: 0.1630. Train acc: 95.90, Val acc: 64.0
# Epoch 1925. Train loss: 0.1900. Train acc: 94.90, Val acc: 49.0
# Epoch 1930. Train loss: 0.2360. Train acc: 93.30, Val acc: 57.0
# Epoch 1935. Train loss: 0.1790. Train acc: 95.60, Val acc: 60.0
# Epoch 1940. Train loss: 0.1540. Train acc: 96.20, Val acc: 49.0
# Epoch 1945. Train loss: 0.1750. Train acc: 95.80, Val acc: 54.0
# Epoch 1950. Train loss: 0.1970. Train acc: 95.10, Val acc: 66.0
# Epoch 1955. Train loss: 0.1750. Train acc: 96.00, Val acc: 63.0
# Epoch 1960. Train loss: 0.1790. Train acc: 95.60, Val acc: 56.0
# Epoch 1965. Train loss: 0.1510. Train acc: 96.60, Val acc: 58.0
# Epoch 1970. Train loss: 0.1680. Train acc: 95.30, Val acc: 58.0
# Epoch 1975. Train loss: 0.1930. Train acc: 95.30, Val acc: 67.0
# Epoch 1980. Train loss: 0.1850. Train acc: 94.90, Val acc: 54.0
# Epoch 1985. Train loss: 0.2480. Train acc: 90.20, Val acc: 61.0
# Epoch 1990. Train loss: 0.4540. Train acc: 80.20, Val acc: 51.0
# Epoch 1995. Train loss: 1.4890. Train acc: 53.50, Val acc: 58.0
# Epoch 2000. Train loss: 0.9470. Train acc: 58.30, Val acc: 49.0
# Epoch 2005. Train loss: 0.6960. Train acc: 72.80, Val acc: 63.0
# Epoch 2010. Train loss: 0.5820. Train acc: 68.10, Val acc: 54.0
# Epoch 2015. Train loss: 0.4970. Train acc: 85.50, Val acc: 60.0
# Epoch 2020. Train loss: 0.5020. Train acc: 80.90, Val acc: 61.0
# Epoch 2025. Train loss: 0.3400. Train acc: 93.20, Val acc: 51.0
# Epoch 2030. Train loss: 0.2890. Train acc: 94.00, Val acc: 54.0
# Epoch 2035. Train loss: 0.2970. Train acc: 92.00, Val acc: 59.0
# Epoch 2040. Train loss: 0.2080. Train acc: 96.70, Val acc: 63.0
# Epoch 2045. Train loss: 0.2110. Train acc: 95.40, Val acc: 58.0
# Epoch 2050. Train loss: 0.1930. Train acc: 96.30, Val acc: 57.0
# Epoch 2055. Train loss: 0.1850. Train acc: 95.80, Val acc: 56.0
# Epoch 2060. Train loss: 0.1820. Train acc: 95.60, Val acc: 68.0
# Epoch 2065. Train loss: 0.1550. Train acc: 96.50, Val acc: 60.0
# Epoch 2070. Train loss: 0.1680. Train acc: 96.60, Val acc: 57.0
# Epoch 2075. Train loss: 0.1710. Train acc: 96.30, Val acc: 56.0
# Epoch 2080. Train loss: 0.1700. Train acc: 96.30, Val acc: 61.0
# Epoch 2085. Train loss: 0.1670. Train acc: 96.10, Val acc: 51.0
# Epoch 2090. Train loss: 0.1660. Train acc: 95.70, Val acc: 56.0
# Epoch 2095. Train loss: 0.1380. Train acc: 97.00, Val acc: 54.0
# Epoch 2100. Train loss: 0.1930. Train acc: 93.90, Val acc: 57.0
# Epoch 2105. Train loss: 0.1620. Train acc: 95.00, Val acc: 54.0
# Epoch 2110. Train loss: 0.1720. Train acc: 95.60, Val acc: 55.0
# Epoch 2115. Train loss: 0.2460. Train acc: 89.10, Val acc: 61.0
# Epoch 2120. Train loss: 0.2040. Train acc: 91.70, Val acc: 58.0
# Epoch 2125. Train loss: 0.1620. Train acc: 95.50, Val acc: 53.0
# Epoch 2130. Train loss: 0.1530. Train acc: 96.20, Val acc: 52.0
# Epoch 2135. Train loss: 0.1210. Train acc: 97.40, Val acc: 55.0
# Epoch 2140. Train loss: 0.1440. Train acc: 96.20, Val acc: 65.0
# Epoch 2145. Train loss: 0.1510. Train acc: 96.30, Val acc: 60.0
# Epoch 2150. Train loss: 0.1140. Train acc: 98.10, Val acc: 56.0
# Epoch 2155. Train loss: 0.1790. Train acc: 95.10, Val acc: 59.0
# Epoch 2160. Train loss: 0.1200. Train acc: 97.50, Val acc: 52.0
# Epoch 2165. Train loss: 0.1820. Train acc: 95.70, Val acc: 56.0
# Epoch 2170. Train loss: 0.3340. Train acc: 85.50, Val acc: 59.0
# Epoch 2175. Train loss: 0.1450. Train acc: 96.90, Val acc: 58.0
# Epoch 2180. Train loss: 0.5220. Train acc: 78.20, Val acc: 63.0
# Epoch 2185. Train loss: 0.2490. Train acc: 90.50, Val acc: 57.0
# Epoch 2190. Train loss: 0.1800. Train acc: 94.70, Val acc: 61.0
# Epoch 2195. Train loss: 0.1830. Train acc: 95.10, Val acc: 45.0
# Epoch 2200. Train loss: 0.1310. Train acc: 97.50, Val acc: 56.0
# Epoch 2205. Train loss: 0.1620. Train acc: 96.30, Val acc: 57.0
# Epoch 2210. Train loss: 0.1680. Train acc: 96.20, Val acc: 56.0
# Epoch 2215. Train loss: 0.1460. Train acc: 96.90, Val acc: 65.0
# Epoch 2220. Train loss: 0.1510. Train acc: 96.90, Val acc: 54.0
# Epoch 2225. Train loss: 0.1300. Train acc: 97.20, Val acc: 57.0
# Epoch 2230. Train loss: 0.1430. Train acc: 96.80, Val acc: 71.0
# Epoch 2235. Train loss: 0.1210. Train acc: 98.00, Val acc: 62.0
# Epoch 2240. Train loss: 0.1110. Train acc: 97.80, Val acc: 63.0
# Epoch 2245. Train loss: 0.1600. Train acc: 96.70, Val acc: 54.0
# Epoch 2250. Train loss: 0.1150. Train acc: 97.60, Val acc: 60.0
# Epoch 2255. Train loss: 0.1240. Train acc: 97.20, Val acc: 63.0
# Epoch 2260. Train loss: 0.1500. Train acc: 96.00, Val acc: 56.0
# Epoch 2265. Train loss: 0.1180. Train acc: 97.80, Val acc: 59.0
# Epoch 2270. Train loss: 0.1620. Train acc: 96.60, Val acc: 54.0
# Epoch 2275. Train loss: 0.1450. Train acc: 96.50, Val acc: 67.0
# Epoch 2280. Train loss: 0.1120. Train acc: 97.40, Val acc: 64.0
# Epoch 2285. Train loss: 0.1020. Train acc: 97.90, Val acc: 56.0
# Epoch 2290. Train loss: 0.1040. Train acc: 97.60, Val acc: 58.0
# Epoch 2295. Train loss: 0.1160. Train acc: 97.50, Val acc: 58.0
# Epoch 2300. Train loss: 0.1100. Train acc: 97.80, Val acc: 60.0
# Epoch 2305. Train loss: 0.1180. Train acc: 97.50, Val acc: 57.0
# Epoch 2310. Train loss: 0.0990. Train acc: 98.40, Val acc: 64.0
# Epoch 2315. Train loss: 0.1390. Train acc: 97.10, Val acc: 55.0
# Epoch 2320. Train loss: 0.1340. Train acc: 97.30, Val acc: 66.0
# Epoch 2325. Train loss: 0.1010. Train acc: 98.00, Val acc: 55.0
# Epoch 2330. Train loss: 0.1170. Train acc: 97.60, Val acc: 57.0
# Epoch 2335. Train loss: 0.1500. Train acc: 96.90, Val acc: 42.0
# Epoch 2340. Train loss: 0.1130. Train acc: 97.80, Val acc: 56.0
# Epoch 2345. Train loss: 0.1460. Train acc: 96.20, Val acc: 59.0
# Epoch 2350. Train loss: 0.1100. Train acc: 97.70, Val acc: 57.0
# Epoch 2355. Train loss: 0.1010. Train acc: 97.80, Val acc: 58.0
# Epoch 2360. Train loss: 0.1230. Train acc: 97.30, Val acc: 50.0
# Epoch 2365. Train loss: 0.7940. Train acc: 74.00, Val acc: 57.0
# Epoch 2370. Train loss: 0.6730. Train acc: 75.10, Val acc: 60.0
# Epoch 2375. Train loss: 0.4430. Train acc: 83.70, Val acc: 64.0
# Epoch 2380. Train loss: 0.5380. Train acc: 77.60, Val acc: 54.0
# Epoch 2385. Train loss: 0.5100. Train acc: 79.20, Val acc: 66.0
# Epoch 2390. Train loss: 0.2290. Train acc: 91.40, Val acc: 55.0
# Epoch 2395. Train loss: 0.1680. Train acc: 96.10, Val acc: 64.0
# Epoch 2400. Train loss: 0.2380. Train acc: 91.40, Val acc: 62.0
# Epoch 2405. Train loss: 0.3600. Train acc: 82.20, Val acc: 64.0
# Epoch 2410. Train loss: 0.2540. Train acc: 90.30, Val acc: 53.0
# Epoch 2415. Train loss: 0.1830. Train acc: 94.30, Val acc: 60.0
# Epoch 2420. Train loss: 0.1490. Train acc: 96.10, Val acc: 62.0
# Epoch 2425. Train loss: 0.1150. Train acc: 98.00, Val acc: 52.0
# Epoch 2430. Train loss: 0.1150. Train acc: 97.60, Val acc: 55.0
# Epoch 2435. Train loss: 0.1000. Train acc: 98.40, Val acc: 58.0
# Epoch 2440. Train loss: 0.1110. Train acc: 97.60, Val acc: 59.0
# Epoch 2445. Train loss: 0.1190. Train acc: 98.00, Val acc: 61.0
# Epoch 2450. Train loss: 0.1130. Train acc: 98.20, Val acc: 59.0
# Epoch 2455. Train loss: 0.0790. Train acc: 98.80, Val acc: 64.0
# Epoch 2460. Train loss: 0.1610. Train acc: 96.70, Val acc: 52.0
# Epoch 2465. Train loss: 0.1220. Train acc: 97.30, Val acc: 63.0
# Epoch 2470. Train loss: 0.1050. Train acc: 97.60, Val acc: 60.0
# Epoch 2475. Train loss: 0.1110. Train acc: 97.70, Val acc: 64.0
# Epoch 2480. Train loss: 0.1280. Train acc: 97.30, Val acc: 55.0
# Epoch 2485. Train loss: 0.1190. Train acc: 97.80, Val acc: 55.0
# Epoch 2490. Train loss: 0.1030. Train acc: 97.90, Val acc: 60.0
# Epoch 2495. Train loss: 0.1190. Train acc: 97.70, Val acc: 51.0
# Epoch 2500. Train loss: 0.1030. Train acc: 98.10, Val acc: 55.0

# %% [markdown]
# # Evaluate the trained neural network model

# %%
plt.plot(i_vals,train_loss, 'g-')
plt.title("Softmax loss for each epoch")
plt.xlabel("Epoch")
plt.ylabel("Softmax loss")
plt.grid()
plt.show()

# %%
plt.plot(i_vals,train_acc, 'r-', label = "Training accuracy")
plt.plot(i_vals,test_acc, 'b-', label = "Validation accuracy")
plt.title("Prediction accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.ylim([0,105])
plt.legend(loc="lower right")
plt.grid()
plt.show()

# %% [markdown]
# ## Evaluate some samples from the training data

# %%
nrows = 2
ncols = 4
m = nrows*ncols
rand_idx = np.random.choice(batch_size, size=m)
actuals = train_labels[rand_idx]
predictions = np.argmax(temp_train_preds, axis=1)[rand_idx]
images = train_images[rand_idx]

for i in range(m):
    plt.subplot(nrows,ncols,i+1)
    plt.imshow(cv2.cvtColor(np.reshape(images[i], [dim,dim,3]),cv2.COLOR_BGR2RGB))
    plt.title("Actual: " +str(actuals[i]) +" Pred: " +str(predictions[i]), fontsize=10)
    frame = plt.gca()
    frame.axes.get_xaxis().set_visible(False)
    frame.axes.get_yaxis().set_visible(False)

# %% [markdown]
# ## Evaluate some samples from the validation data

# %%
nrows = 2
ncols = 4
m = nrows*ncols
rand_idx = np.random.choice(evaluation_size, size=m)
actuals = validation_labels[rand_idx]
predictions = np.argmax(temp_test_preds, axis=1)[rand_idx]
images = validation_images[rand_idx]

for i in range(m):
    plt.subplot(nrows,ncols,i+1)
    plt.imshow(cv2.cvtColor(np.reshape(images[i], [dim,dim,3]),cv2.COLOR_BGR2RGB))
    plt.title("Actual: " +str(actuals[i]) +" Pred: " +str(predictions[i]), fontsize=10)
    frame = plt.gca()
    frame.axes.get_xaxis().set_visible(False)
    frame.axes.get_yaxis().set_visible(False)

# %% [markdown]
# ## Evaluate some samples from the test data
# ### It requires updating the model file name according to the lastest epoch!

# %%
#Test dataset
test_images = []
test_labels = []

files = glob.glob ("cats_and_dogs_small/test/cats/*.jpg")
for myFile in files:
    image = cv2.imread(myFile)
    image = cv2.resize(image,(dim,dim))

    test_images.append(image)

    test_labels.append(0)#Class for cats

    cv2.imshow("Cat samples - Test", image)
    cv2.waitKey(1)
cv2.destroyAllWindows()

files = glob.glob ("cats_and_dogs_small/test/dogs/*.jpg")
for myFile in files:
    image = cv2.imread(myFile)
    image = cv2.resize(image,(dim,dim))

    r = np.random.choice(len(train_labels))

    test_images.insert(r,image)

    test_labels.insert(r,1)#Class for dogs

    cv2.imshow("Dog samples - Test ", image)
    cv2.waitKey(1)
cv2.destroyAllWindows()

#Input and output data
test_xdata = np.array(test_images,np.float64)/255
test_labels = np.array(test_labels,np.int32)

test_images = np.array(test_images)

#Print dimensions
print(test_images.shape)
print(test_labels.shape)
# Out:
# (1000, 64, 64, 3)
# (1000,)

# %%
#### RUN NN
rand_idx_eval = np.random.choice(len(test_xdata), size=evaluation_size)
rand_x_eval = test_xdata[rand_idx_eval]
rand_y_eval = test_labels[rand_idx_eval]

test_dict = {eval_input: rand_x_eval, eval_target: rand_y_eval}

#### Restore variables
#It requires updating the file name according to the lastest training epoch!
saver.restore(session,'nn_model/my_model-2500')
temp_test_preds = session.run(test_prediction, feed_dict = test_dict)

##### Print results
nrows = 2
ncols = 4
m = nrows*ncols
rand_idx = np.random.choice(evaluation_size, size=m)
actuals = test_labels[rand_idx]
predictions = np.argmax(temp_test_preds, axis=1)[rand_idx]
images = test_images[rand_idx]

for i in range(m):
    plt.subplot(nrows,ncols,i+1)
    plt.imshow(cv2.cvtColor(np.reshape(images[i], [dim,dim,3]),cv2.COLOR_BGR2RGB))
    plt.title("Actual: " +str(actuals[i]) +" Pred: " +str(predictions[i]), fontsize=10)
    frame = plt.gca()
    frame.axes.get_xaxis().set_visible(False)
    frame.axes.get_yaxis().set_visible(False)
# Out:
# INFO:tensorflow:Restoring parameters from nn_model/my_model-2500
